# %%
import numpy as np
import scipy as sp
from scipy import stats
X = np.random.rand(20)
X
# Out:
# array([0.22529453, 0.93565606, 0.98709784, 0.42044751, 0.55711089,
#        0.75768334, 0.23905783, 0.50383835, 0.40500435, 0.70495658,
#        0.5204048 , 0.59554166, 0.17596766, 0.617903  , 0.94889664,
#        0.48235497, 0.12115139, 0.92142268, 0.50624311, 0.24187762])

# %%
#class stats.rv_continuous(momtype=1, a=None, b=None, xtol=1e-14, badvalue=None, name=None, longname=None, shapes=None, extradoc=None, seed=None)
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True

N = 500
data = np.random.randn(N)
count, bins_count = np.histogram(X)
pdf = count / sum(count)
#cdf = np.cumsum(pdf)
plt.plot(bins_count[1:], cdf, label="CDF")
plt.legend()
plt.show()

# %%
N = 500
data = np.random.randn(N)
count, bins_count = np.histogram(X)
pdf = count / sum(count)
#cdf = np.cumsum(pdf)
plt.plot(bins_count[1:], pdf, label="PDF")
plt.legend()
plt.show()

# %%
count
# Out:
# array([6, 3, 3, 0, 2, 0, 2, 0, 1, 3])
